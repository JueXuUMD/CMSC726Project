# %%
import time
import numpy as np
import torch
import torchvision
from torchmps import MPS
from torchvision import transforms, datasets

import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 400
mpl.rcParams['text.usetex'] = True

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# Miscellaneous initialization
torch.manual_seed(0)

# functions to show an image
def imshow(img):
#     img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()
    
# functions to load data
def load_data(dataset):
    # Get the training and test sets
    if  dataset == 'cifar':
#         transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
        transform = transforms.Compose([transforms.Grayscale(num_output_channels=1), transforms.ToTensor()])
    else:
        transform = transforms.ToTensor()
    print("=====================================")
    print("The dataset we are training:", dataset)
    if  dataset == 'mnist':
        train_set = datasets.MNIST('./mnist', download=True, transform=transform)
        test_set = datasets.MNIST('./mnist', download=True, transform=transform, train=False)
    elif dataset == 'fashionmnist':
        train_set = datasets.FashionMNIST('./fashionmnist', download=True, transform=transform)
        test_set = datasets.FashionMNIST('./fashionmnist', download=True, transform=transform, train=False)
    elif dataset == 'cifar':
        train_set = datasets.CIFAR10('./CIFAR10', download=True, transform=transform)
        test_set = datasets.CIFAR10('./CIFAR10', download=True, transform=transform, train=False)

    # classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

    # print(len(train_set))
    dim = len(train_set[1][0][0])
    num_channel = len(train_set[1][0])

    # Put MNIST data into dataloaders
    samplers = {'train': torch.utils.data.SubsetRandomSampler(range(num_train)),
                'test': torch.utils.data.SubsetRandomSampler(range(num_test))}
    loaders = {name: torch.utils.data.DataLoader(dataset, batch_size=batch_size, 
               sampler=samplers[name], drop_last=True) for (name, dataset) in 
               [('train', train_set), ('test', test_set)]}
    num_batches = {name: total_num // batch_size for (name, total_num) in
                   [('train', num_train), ('test', num_test)]}

    print(f"Training on {num_train} images \n"
          f"(testing on {num_test}) for {num_epochs} epochs")
    print(f"Maximum MPS bond dimension = {bond_dim}")
    print(f" * {'Adaptive' if adaptive_mode else 'Fixed'} bond dimensions")
    print(f" * {'Periodic' if periodic_bc else 'Open'} boundary conditions")
    print(f"Using Adam w/ learning rate = {learn_rate:.1e}")
    if l2_reg > 0:
        print(f" * L2 regularization = {l2_reg:.2e}")
    print()
#     print(np.size(train_set[1]))
          
    return samplers, loaders, num_batches, dim, num_channel
          
# Let's start training!
def mps_train(loaders, num_channel):
    # Initialize the MPS module
    mps = MPS(input_dim=dim**2, output_dim=10, bond_dim=bond_dim, 
              adaptive_mode=adaptive_mode, periodic_bc=periodic_bc)

    # Set our loss function and optimizer
    loss_fun = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(mps.parameters(), lr=learn_rate, 
                                 weight_decay=l2_reg)

    if num_channel == 3:
        size = [num_channel, batch_size, dim**2]
    else:
        size = [batch_size, dim**2]
          
          
    train_acc = []
    test_acc  = []
    ave_loss = []
    run_time = []
          
    for epoch_num in range(1, num_epochs+1):
        running_loss = 0.
        running_acc = 0.

        for inputs, labels in loaders['train']:
            inputs, labels = inputs.view(size), labels.data

            # Call our MPS to get logit scores and predictions
            scores = mps(inputs)
            _, preds = torch.max(scores, 1)

            # Compute the loss and accuracy, add them to the running totals
            loss = loss_fun(scores, labels)
            with torch.no_grad():
                accuracy = torch.sum(preds == labels).item() / batch_size
                running_loss += loss
                running_acc += accuracy

            # Backpropagate and update parameters
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        print(f"### Epoch {epoch_num} ###")
        print(f"Average loss:           {running_loss / num_batches['train']:.4f}")
        train_acc = train_acc + [ running_acc / num_batches['train'] ]
        print(f"Average train accuracy: {running_acc / num_batches['train']:.4f}")
        ave_loss = ave_loss + [ running_loss / num_batches['train'] ]

        # Evaluate accuracy of MPS classifier on the test set
        with torch.no_grad():
            running_acc = 0.
              
            for inputs, labels in loaders['test']:
                inputs, labels = inputs.view(size), labels.data

                # Call our MPS to get logit scores and predictions
                scores = mps(inputs)
                _, preds = torch.max(scores, 1)
                running_acc += torch.sum(preds == labels).item() / batch_size

        print(f"Test accuracy:          {running_acc / num_batches['test']:.4f}")
        test_acc = test_acc + [ running_acc / num_batches['test'] ]
        print(f"Runtime so far:         {int(time.time()-start_time)} sec\n")
        run_time = run_time + [ int(time.time()-start_time) ]
#         print(test_acc)
              
    return run_time, ave_loss, train_acc, test_acc

# %%
# MPS parameters
bond_dim      = 20
adaptive_mode = False
periodic_bc   = False

# Training parameters
num_train  = 2000
num_test   = 1000
batch_size = 100
num_epochs = 40
learn_rate = 1e-4
l2_reg     = 0.

# choose dataset
# data    = 'mnist'
# data    = 'fashionmnist'
# data    = 'cifar'

TRAIN_ACC = []
TEST_ACC  = []
AVE_LOSS = []
RUN_TIME = []

for data in ['cifar', 'mnist', 'fashionmnist']:
# for data in ['mnist', 'fashionmnist']:
    start_time = time.time()
    samplers, loaders, num_batches, dim, num_channel = load_data(data)

    # visualization
    # get some random training images
    dataiter = iter(loaders['train'])
    images, labels = dataiter.next()
    # show images
    imshow(torchvision.utils.make_grid(images))
    # print labels
    # print(' '.join('%5s' % classes[labels[j]] for j in range(4)))

    # training
    run_time, ave_loss, train_acc, test_acc = mps_train(loaders, num_channel)
    TRAIN_ACC = TRAIN_ACC + [train_acc]
    TEST_ACC  = TEST_ACC  + [test_acc]
    AVE_LOSS  = AVE_LOSS  + [ave_loss]
    RUN_TIME  = RUN_TIME  + [run_time]
# Out:
# =====================================
# The dataset we are training: cifar
# Files already downloaded and verified
# Files already downloaded and verified
# Training on 2000 images
# (testing on 1000) for 40 epochs
# Maximum MPS bond dimension = 20
#  * Fixed bond dimensions
#  * Open boundary conditions
# Using Adam w/ learning rate = 1.0e-04
# ### Epoch 1 ###
# Average loss:           2.2860
# Average train accuracy: 0.1255
# Test accuracy:          0.1240
# Runtime so far:         37 sec
#
# ### Epoch 2 ###
# Average loss:           2.2476
# Average train accuracy: 0.1330
# Test accuracy:          0.1560
# Runtime so far:         74 sec
#
# ### Epoch 3 ###
# Average loss:           2.1959
# Average train accuracy: 0.1865
# Test accuracy:          0.2050
# Runtime so far:         111 sec
#
# ### Epoch 4 ###
# Average loss:           2.1782
# Average train accuracy: 0.1965
# Test accuracy:          0.2170
# Runtime so far:         147 sec
#
# ### Epoch 5 ###
# Average loss:           2.1212
# Average train accuracy: 0.2100
# Test accuracy:          0.2220
# Runtime so far:         184 sec
#
# ### Epoch 6 ###
# Average loss:           2.0943
# Average train accuracy: 0.2250
# Test accuracy:          0.2240
# Runtime so far:         220 sec
#
# ### Epoch 7 ###
# Average loss:           2.0815
# Average train accuracy: 0.2320
# Test accuracy:          0.2400
# Runtime so far:         256 sec
#
# ### Epoch 8 ###
# Average loss:           2.0459
# Average train accuracy: 0.2515
# Test accuracy:          0.2470
# Runtime so far:         293 sec
#
# ### Epoch 9 ###
# Average loss:           2.0273
# Average train accuracy: 0.2665
# Test accuracy:          0.2390
# Runtime so far:         329 sec
#
# ### Epoch 10 ###
# Average loss:           1.9945
# Average train accuracy: 0.2735
# Test accuracy:          0.2540
# Runtime so far:         366 sec
#
# ### Epoch 11 ###
# Average loss:           1.9663
# Average train accuracy: 0.2930
# Test accuracy:          0.2690
# Runtime so far:         402 sec
#
# ### Epoch 12 ###
# Average loss:           1.9493
# Average train accuracy: 0.2845
# Test accuracy:          0.2600
# Runtime so far:         439 sec
#
# ### Epoch 13 ###
# Average loss:           1.9184
# Average train accuracy: 0.3065
# Test accuracy:          0.2440
# Runtime so far:         475 sec
#
# ### Epoch 14 ###
# Average loss:           1.8992
# Average train accuracy: 0.3130
# Test accuracy:          0.2860
# Runtime so far:         512 sec
#
# ### Epoch 15 ###
# Average loss:           1.8951
# Average train accuracy: 0.3160
# Test accuracy:          0.2740
# Runtime so far:         548 sec
#
# ### Epoch 16 ###
# Average loss:           1.8593
# Average train accuracy: 0.3230
# Test accuracy:          0.2730
# Runtime so far:         585 sec
#
# ### Epoch 17 ###
# Average loss:           1.8722
# Average train accuracy: 0.3240
# Test accuracy:          0.2520
# Runtime so far:         622 sec
#
# ### Epoch 18 ###
# Average loss:           1.8558
# Average train accuracy: 0.3260
# Test accuracy:          0.2630
# Runtime so far:         658 sec
#
# ### Epoch 19 ###
# Average loss:           1.8249
# Average train accuracy: 0.3575
# Test accuracy:          0.2900
# Runtime so far:         695 sec
#
# ### Epoch 20 ###
# Average loss:           1.7948
# Average train accuracy: 0.3380
# Test accuracy:          0.2920
# Runtime so far:         731 sec
#
# ### Epoch 21 ###
# Average loss:           1.7611
# Average train accuracy: 0.3625
# Test accuracy:          0.2960
# Runtime so far:         767 sec
#
# ### Epoch 22 ###
# Average loss:           1.7472
# Average train accuracy: 0.3760
# Test accuracy:          0.2920
# Runtime so far:         804 sec
#
# ### Epoch 23 ###
# Average loss:           1.6955
# Average train accuracy: 0.3685
# Test accuracy:          0.2920
# Runtime so far:         840 sec
#
# ### Epoch 24 ###
# Average loss:           1.6995
# Average train accuracy: 0.3835
# Test accuracy:          0.2670
# Runtime so far:         877 sec
#
# ### Epoch 25 ###
# Average loss:           1.6645
# Average train accuracy: 0.3930
# Test accuracy:          0.2800
# Runtime so far:         914 sec
#
# ### Epoch 26 ###
# Average loss:           1.6389
# Average train accuracy: 0.3995
# Test accuracy:          0.2980
# Runtime so far:         951 sec
#
# ### Epoch 27 ###
# Average loss:           1.5761
# Average train accuracy: 0.4370
# Test accuracy:          0.2980
# Runtime so far:         987 sec
#
# ### Epoch 28 ###
# Average loss:           1.5433
# Average train accuracy: 0.4470
# Test accuracy:          0.2920
# Runtime so far:         1024 sec
#
# ### Epoch 29 ###
# Average loss:           1.5458
# Average train accuracy: 0.4380
# Test accuracy:          0.3040
# Runtime so far:         1060 sec
#
# ### Epoch 30 ###
# Average loss:           1.5557
# Average train accuracy: 0.4400
# Test accuracy:          0.2900
# Runtime so far:         1097 sec
#
# ### Epoch 31 ###
# Average loss:           1.4849
# Average train accuracy: 0.4675
# Test accuracy:          0.2910
# Runtime so far:         1133 sec
#
# ### Epoch 32 ###
# Average loss:           1.4529
# Average train accuracy: 0.4710
# Test accuracy:          0.3040
# Runtime so far:         1170 sec
#
# ### Epoch 33 ###
# Average loss:           1.4630
# Average train accuracy: 0.4635
# Test accuracy:          0.2780
# Runtime so far:         1206 sec
#
# ### Epoch 34 ###
# Average loss:           1.3776
# Average train accuracy: 0.5040
# Test accuracy:          0.2800
# Runtime so far:         1242 sec
#
# ### Epoch 35 ###
# Average loss:           1.3706
# Average train accuracy: 0.5125
# Test accuracy:          0.2910
# Runtime so far:         1279 sec
#
# ### Epoch 36 ###
# Average loss:           1.3793
# Average train accuracy: 0.5205
# Test accuracy:          0.2950
# Runtime so far:         1315 sec
#
# ### Epoch 37 ###
# Average loss:           1.3208
# Average train accuracy: 0.5155
# Test accuracy:          0.2860
# Runtime so far:         1352 sec
#
# ### Epoch 38 ###
# Average loss:           1.2756
# Average train accuracy: 0.5395
# Test accuracy:          0.2990
# Runtime so far:         1389 sec
#
# ### Epoch 39 ###
# Average loss:           1.2400
# Average train accuracy: 0.5465
# Test accuracy:          0.2980
# Runtime so far:         1425 sec
#
# ### Epoch 40 ###
# Average loss:           1.2004
# Average train accuracy: 0.5745
# Test accuracy:          0.3060
# Runtime so far:         1462 sec
#
# =====================================
# The dataset we are training: mnist
# Training on 2000 images
# (testing on 1000) for 40 epochs
# Maximum MPS bond dimension = 20
#  * Fixed bond dimensions
#  * Open boundary conditions
# Using Adam w/ learning rate = 1.0e-04
# ### Epoch 1 ###
# Average loss:           2.2567
# Average train accuracy: 0.1375
# Test accuracy:          0.2560
# Runtime so far:         29 sec
#
# ### Epoch 2 ###
# Average loss:           1.4350
# Average train accuracy: 0.5055
# Test accuracy:          0.6070
# Runtime so far:         57 sec
#
# ### Epoch 3 ###
# Average loss:           0.9082
# Average train accuracy: 0.6855
# Test accuracy:          0.6820
# Runtime so far:         86 sec
#
# ### Epoch 4 ###
# Average loss:           0.6432
# Average train accuracy: 0.7930
# Test accuracy:          0.7550
# Runtime so far:         114 sec
#
# ### Epoch 5 ###
# Average loss:           0.4682
# Average train accuracy: 0.8590
# Test accuracy:          0.8070
# Runtime so far:         143 sec
#
# ### Epoch 6 ###
# Average loss:           0.3697
# Average train accuracy: 0.8880
# Test accuracy:          0.8100
# Runtime so far:         171 sec
#
# ### Epoch 7 ###
# Average loss:           0.3060
# Average train accuracy: 0.9045
# Test accuracy:          0.8400
# Runtime so far:         200 sec
#
# ### Epoch 8 ###
# Average loss:           0.2360
# Average train accuracy: 0.9205
# Test accuracy:          0.8420
# Runtime so far:         228 sec
#
# ### Epoch 9 ###
# Average loss:           0.2105
# Average train accuracy: 0.9305
# Test accuracy:          0.8510
# Runtime so far:         257 sec
#
# ### Epoch 10 ###
# Average loss:           0.1647
# Average train accuracy: 0.9425
# Test accuracy:          0.8520
# Runtime so far:         285 sec
#
# ### Epoch 11 ###
# Average loss:           0.1633
# Average train accuracy: 0.9405
# Test accuracy:          0.8430
# Runtime so far:         313 sec
#
# ### Epoch 12 ###
# Average loss:           0.1475
# Average train accuracy: 0.9445
# Test accuracy:          0.8510
# Runtime so far:         342 sec
#
# ### Epoch 13 ###
# Average loss:           0.1056
# Average train accuracy: 0.9665
# Test accuracy:          0.8680
# Runtime so far:         370 sec
#
# ### Epoch 14 ###
# Average loss:           0.1252
# Average train accuracy: 0.9595
# Test accuracy:          0.8710
# Runtime so far:         398 sec
#
# ### Epoch 15 ###
# Average loss:           0.1438
# Average train accuracy: 0.9525
# Test accuracy:          0.8680
# Runtime so far:         427 sec
#
# ### Epoch 16 ###
# Average loss:           0.0957
# Average train accuracy: 0.9690
# Test accuracy:          0.8700
# Runtime so far:         455 sec
#
# ### Epoch 17 ###
# Average loss:           0.0676
# Average train accuracy: 0.9785
# Test accuracy:          0.8900
# Runtime so far:         484 sec
#
# ### Epoch 18 ###
# Average loss:           0.0583
# Average train accuracy: 0.9780
# Test accuracy:          0.8740
# Runtime so far:         513 sec
#
# ### Epoch 19 ###
# Average loss:           0.0638
# Average train accuracy: 0.9805
# Test accuracy:          0.8780
# Runtime so far:         541 sec
#
# ### Epoch 20 ###
# Average loss:           0.0488
# Average train accuracy: 0.9870
# Test accuracy:          0.8800
# Runtime so far:         569 sec
#
# ### Epoch 21 ###
# Average loss:           0.0476
# Average train accuracy: 0.9855
# Test accuracy:          0.8950
# Runtime so far:         598 sec
#
# ### Epoch 22 ###
# Average loss:           0.0768
# Average train accuracy: 0.9770
# Test accuracy:          0.8550
# Runtime so far:         626 sec
#
# ### Epoch 23 ###
# Average loss:           0.0619
# Average train accuracy: 0.9785
# Test accuracy:          0.8990
# Runtime so far:         655 sec
#
# ### Epoch 24 ###
# Average loss:           0.0358
# Average train accuracy: 0.9885
# Test accuracy:          0.8970
# Runtime so far:         683 sec
#
# ### Epoch 25 ###
# Average loss:           0.0381
# Average train accuracy: 0.9885
# Test accuracy:          0.8850
# Runtime so far:         712 sec
#
# ### Epoch 26 ###
# Average loss:           0.0302
# Average train accuracy: 0.9915
# Test accuracy:          0.8890
# Runtime so far:         740 sec
#
# ### Epoch 27 ###
# Average loss:           0.0142
# Average train accuracy: 0.9955
# Test accuracy:          0.8880
# Runtime so far:         768 sec
#
# ### Epoch 28 ###
# Average loss:           0.0162
# Average train accuracy: 0.9930
# Test accuracy:          0.8760
# Runtime so far:         797 sec
#
# ### Epoch 29 ###
# Average loss:           0.0594
# Average train accuracy: 0.9820
# Test accuracy:          0.8870
# Runtime so far:         825 sec
#
# ### Epoch 30 ###
# Average loss:           0.0495
# Average train accuracy: 0.9900
# Test accuracy:          0.8440
# Runtime so far:         854 sec
#
# ### Epoch 31 ###
# Average loss:           0.1030
# Average train accuracy: 0.9760
# Test accuracy:          0.8940
# Runtime so far:         882 sec
#
# ### Epoch 32 ###
# Average loss:           0.0364
# Average train accuracy: 0.9895
# Test accuracy:          0.9000
# Runtime so far:         911 sec
#
# ### Epoch 33 ###
# Average loss:           0.0276
# Average train accuracy: 0.9925
# Test accuracy:          0.8890
# Runtime so far:         940 sec
#
# ### Epoch 34 ###
# Average loss:           0.0143
# Average train accuracy: 0.9950
# Test accuracy:          0.8960
# Runtime so far:         968 sec
#
# ### Epoch 35 ###
# Average loss:           0.0117
# Average train accuracy: 0.9975
# Test accuracy:          0.9020
# Runtime so far:         996 sec
#
# ### Epoch 36 ###
# Average loss:           0.0135
# Average train accuracy: 0.9960
# Test accuracy:          0.8870
# Runtime so far:         1025 sec
#
# ### Epoch 37 ###
# Average loss:           0.0033
# Average train accuracy: 0.9990
# Test accuracy:          0.8940
# Runtime so far:         1053 sec
#
# ### Epoch 38 ###
# Average loss:           0.0342
# Average train accuracy: 0.9890
# Test accuracy:          0.8880
# Runtime so far:         1081 sec
#
# ### Epoch 39 ###
# Average loss:           0.0355
# Average train accuracy: 0.9890
# Test accuracy:          0.8830
# Runtime so far:         1110 sec
#
# ### Epoch 40 ###
# Average loss:           0.0665
# Average train accuracy: 0.9815
# Test accuracy:          0.8350
# Runtime so far:         1138 sec
#
# =====================================
# The dataset we are training: fashionmnist
# Training on 2000 images
# (testing on 1000) for 40 epochs
# Maximum MPS bond dimension = 20
#  * Fixed bond dimensions
#  * Open boundary conditions
# Using Adam w/ learning rate = 1.0e-04
# ### Epoch 1 ###
# Average loss:           2.1940
# Average train accuracy: 0.1280
# Test accuracy:          0.2000
# Runtime so far:         29 sec
#
# ### Epoch 2 ###
# Average loss:           1.6580
# Average train accuracy: 0.3060
# Test accuracy:          0.3910
# Runtime so far:         57 sec
#
# ### Epoch 3 ###
# Average loss:           1.2017
# Average train accuracy: 0.5095
# Test accuracy:          0.5890
# Runtime so far:         85 sec
#
# ### Epoch 4 ###
# Average loss:           0.9473
# Average train accuracy: 0.6305
# Test accuracy:          0.6370
# Runtime so far:         114 sec
#
# ### Epoch 5 ###
# Average loss:           0.7942
# Average train accuracy: 0.6905
# Test accuracy:          0.6710
# Runtime so far:         142 sec
#
# ### Epoch 6 ###
# Average loss:           0.7053
# Average train accuracy: 0.7220
# Test accuracy:          0.6380
# Runtime so far:         171 sec
#
# ### Epoch 7 ###
# Average loss:           0.6903
# Average train accuracy: 0.7235
# Test accuracy:          0.6920
# Runtime so far:         199 sec
#
# ### Epoch 8 ###
# Average loss:           0.6460
# Average train accuracy: 0.7590
# Test accuracy:          0.6980
# Runtime so far:         227 sec
#
# ### Epoch 9 ###
# Average loss:           0.6123
# Average train accuracy: 0.7640
# Test accuracy:          0.7160
# Runtime so far:         256 sec
#
# ### Epoch 10 ###
# Average loss:           0.5402
# Average train accuracy: 0.7755
# Test accuracy:          0.7400
# Runtime so far:         284 sec
#
# ### Epoch 11 ###
# Average loss:           0.5267
# Average train accuracy: 0.7875
# Test accuracy:          0.7330
# Runtime so far:         312 sec
#
# ### Epoch 12 ###
# Average loss:           0.4965
# Average train accuracy: 0.8030
# Test accuracy:          0.7260
# Runtime so far:         341 sec
#
# ### Epoch 13 ###
# Average loss:           0.4647
# Average train accuracy: 0.8155
# Test accuracy:          0.7700
# Runtime so far:         370 sec
#
# ### Epoch 14 ###
# Average loss:           0.4360
# Average train accuracy: 0.8295
# Test accuracy:          0.7440
# Runtime so far:         398 sec
#
# ### Epoch 15 ###
# Average loss:           0.4398
# Average train accuracy: 0.8330
# Test accuracy:          0.7680
# Runtime so far:         426 sec
#
# ### Epoch 16 ###
# Average loss:           0.3910
# Average train accuracy: 0.8420
# Test accuracy:          0.7810
# Runtime so far:         455 sec
#
# ### Epoch 17 ###
# Average loss:           0.3693
# Average train accuracy: 0.8555
# Test accuracy:          0.7900
# Runtime so far:         483 sec
#
# ### Epoch 18 ###
# Average loss:           0.3530
# Average train accuracy: 0.8565
# Test accuracy:          0.7900
# Runtime so far:         511 sec
#
# ### Epoch 19 ###
# Average loss:           0.3273
# Average train accuracy: 0.8755
# Test accuracy:          0.7950
# Runtime so far:         540 sec
#
# ### Epoch 20 ###
# Average loss:           0.3352
# Average train accuracy: 0.8730
# Test accuracy:          0.8050
# Runtime so far:         568 sec
#
# ### Epoch 21 ###
# Average loss:           0.3295
# Average train accuracy: 0.8765
# Test accuracy:          0.7850
# Runtime so far:         597 sec
#
# ### Epoch 22 ###
# Average loss:           0.3238
# Average train accuracy: 0.8840
# Test accuracy:          0.7920
# Runtime so far:         625 sec
#
# ### Epoch 23 ###
# Average loss:           0.2851
# Average train accuracy: 0.8895
# Test accuracy:          0.8140
# Runtime so far:         654 sec
#
# ### Epoch 24 ###
# Average loss:           0.2631
# Average train accuracy: 0.9030
# Test accuracy:          0.7950
# Runtime so far:         682 sec
#
# ### Epoch 25 ###
# Average loss:           0.3018
# Average train accuracy: 0.8905
# Test accuracy:          0.7940
# Runtime so far:         711 sec
#
# ### Epoch 26 ###
# Average loss:           0.2915
# Average train accuracy: 0.8945
# Test accuracy:          0.7930
# Runtime so far:         740 sec
#
# ### Epoch 27 ###
# Average loss:           0.2504
# Average train accuracy: 0.9010
# Test accuracy:          0.8110
# Runtime so far:         768 sec
#
# ### Epoch 28 ###
# Average loss:           0.2146
# Average train accuracy: 0.9170
# Test accuracy:          0.8180
# Runtime so far:         797 sec
#
# ### Epoch 29 ###
# Average loss:           0.2453
# Average train accuracy: 0.9050
# Test accuracy:          0.7990
# Runtime so far:         825 sec
#
# ### Epoch 30 ###
# Average loss:           0.2224
# Average train accuracy: 0.9140
# Test accuracy:          0.8030
# Runtime so far:         854 sec
#
# ### Epoch 31 ###
# Average loss:           0.2196
# Average train accuracy: 0.9180
# Test accuracy:          0.8210
# Runtime so far:         882 sec
#
# ### Epoch 32 ###
# Average loss:           0.2046
# Average train accuracy: 0.9240
# Test accuracy:          0.8040
# Runtime so far:         910 sec
#
# ### Epoch 33 ###
# Average loss:           0.2092
# Average train accuracy: 0.9185
# Test accuracy:          0.8240
# Runtime so far:         939 sec
#
# ### Epoch 34 ###
# Average loss:           0.2142
# Average train accuracy: 0.9200
# Test accuracy:          0.8110
# Runtime so far:         967 sec
#
# ### Epoch 35 ###
# Average loss:           0.1795
# Average train accuracy: 0.9350
# Test accuracy:          0.8130
# Runtime so far:         995 sec
#
# ### Epoch 36 ###
# Average loss:           0.1649
# Average train accuracy: 0.9400
# Test accuracy:          0.8120
# Runtime so far:         1024 sec
#
# ### Epoch 37 ###
# Average loss:           0.1756
# Average train accuracy: 0.9375
# Test accuracy:          0.8190
# Runtime so far:         1052 sec
#
# ### Epoch 38 ###
# Average loss:           0.1683
# Average train accuracy: 0.9370
# Test accuracy:          0.8100
# Runtime so far:         1081 sec
#
# ### Epoch 39 ###
# Average loss:           0.1560
# Average train accuracy: 0.9375
# Test accuracy:          0.8040
# Runtime so far:         1109 sec
#
# ### Epoch 40 ###
# Average loss:           0.1647
# Average train accuracy: 0.9400
# Test accuracy:          0.7870
# Runtime so far:         1138 sec

# %%
## Visualization
epoch_num = [range(len(i)) for i in RUN_TIME]
fig, (ax0, ax1) = plt.subplots(ncols=1, nrows=2, figsize=(8, 6))
# fig, (ax0, ax1, ax2, ax3) = plt.subplots(ncols=1, nrows=4, figsize=(6, 12))
# y2= 
# y2= 
ax0.plot(epoch_num[1], AVE_LOSS[1], 'bo-')
ax0.plot(epoch_num[2], AVE_LOSS[2], 'ro-')
ax0.plot(epoch_num[0], AVE_LOSS[0], 'go-')
ax1.plot(epoch_num[1], TRAIN_ACC[1], 'b.-')
ax1.plot(epoch_num[2], TRAIN_ACC[2], 'r.-')
ax1.plot(epoch_num[0], TRAIN_ACC[0], 'g.-')
ax1.plot(epoch_num[1], TEST_ACC[1], 'b--')
ax1.plot(epoch_num[2], TEST_ACC[2], 'r--')
ax1.plot(epoch_num[0], TEST_ACC[0], 'g--')
# ax3.plot(epoch_num[0], RUN_TIME[0], 'bo-')
# ax3.plot(epoch_num[1], RUN_TIME[1], 'ro-')
# ax.plot(x, y2, 'ro--')
# ax.plot(x, y3, 'g.--', markersize=5)
# ax.plot(x, y4, 'y-', linewidth=2)
# ax.set_xlim(0, 7)
# ax.set_ylim(-1, 1.5)
# ax.set_xlabel(r'Running time')
# ax3.set_xlabel(r'Number of epochs')
ax1.set_xlabel(r'Number of epochs',fontsize=16)
ax0.set_ylabel('Average Loss', fontname='Times', fontsize=16)
ax1.set_ylabel('Accuracy',fontsize=16)
# ax2.set_ylabel('Test Accuracy')
# ax3.set_ylabel('Running Time(s)')
ax0.set_title('')
# ax.text(4, 0.4, r'$$')

ax0.legend(('MNIST','FashionMNIST','CIFAR10'), loc='upper right')
ax1.legend(('MNIST(train)','FashionMNIST(train)','CIFAR(train)','MNIST(test)','FashionMNIST(test)','CIFAR(test)',), loc='lower right')
# ax2.legend(('Mnist','Fashionmnist'), loc='lower right')
# ax3.legend(('Mnist','Fashionmnist'), loc='lower right')
fig.savefig('test.png', transparent=True, dpi=400)

# %%
AVE_LOSS
# Out:
# [[tensor(2.2860),
#   tensor(2.2476),
#   tensor(2.1959),
#   tensor(2.1782),
#   tensor(2.1212),
#   tensor(2.0943),
#   tensor(2.0815),
#   tensor(2.0459),
#   tensor(2.0273),
#   tensor(1.9945),
#   tensor(1.9663),
#   tensor(1.9493),
#   tensor(1.9184),
#   tensor(1.8992),
#   tensor(1.8951),
#   tensor(1.8593),
#   tensor(1.8722),
#   tensor(1.8558),
#   tensor(1.8249),
#   tensor(1.7948),
#   tensor(1.7611),
#   tensor(1.7472),
#   tensor(1.6955),
#   tensor(1.6995),
#   tensor(1.6645),
#   tensor(1.6389),
#   tensor(1.5761),
#   tensor(1.5433),
#   tensor(1.5458),
#   tensor(1.5557),
#   tensor(1.4849),
#   tensor(1.4529),
#   tensor(1.4630),
#   tensor(1.3776),
#   tensor(1.3706),
#   tensor(1.3793),
#   tensor(1.3208),
#   tensor(1.2756),
#   tensor(1.2400),
#   tensor(1.2004)],
#  [tensor(2.2567),
#   tensor(1.4350),
#   tensor(0.9082),
#   tensor(0.6432),
#   tensor(0.4682),
#   tensor(0.3697),
#   tensor(0.3060),
#   tensor(0.2360),
#   tensor(0.2105),
#   tensor(0.1647),
#   tensor(0.1633),
#   tensor(0.1475),
#   tensor(0.1056),
#   tensor(0.1252),
#   tensor(0.1438),
#   tensor(0.0957),
#   tensor(0.0676),
#   tensor(0.0583),
#   tensor(0.0638),
#   tensor(0.0488),
#   tensor(0.0476),
#   tensor(0.0768),
#   tensor(0.0619),
#   tensor(0.0358),
#   tensor(0.0381),
#   tensor(0.0302),
#   tensor(0.0142),
#   tensor(0.0162),
#   tensor(0.0594),
#   tensor(0.0495),
#   tensor(0.1030),
#   tensor(0.0364),
#   tensor(0.0276),
#   tensor(0.0143),
#   tensor(0.0117),
#   tensor(0.0135),
#   tensor(0.0033),
#   tensor(0.0342),
#   tensor(0.0355),
#   tensor(0.0665)],
#  [tensor(2.1940),
#   tensor(1.6580),
#   tensor(1.2017),
#   tensor(0.9473),
#   tensor(0.7942),
#   tensor(0.7053),
#   tensor(0.6903),
#   tensor(0.6460),
#   tensor(0.6123),
#   tensor(0.5402),
#   tensor(0.5267),
#   tensor(0.4965),
#   tensor(0.4647),
#   tensor(0.4360),
#   tensor(0.4398),
#   tensor(0.3910),
#   tensor(0.3693),
#   tensor(0.3530),
#   tensor(0.3273),
#   tensor(0.3352),
#   tensor(0.3295),
#   tensor(0.3238),
#   tensor(0.2851),
#   tensor(0.2631),
#   tensor(0.3018),
#   tensor(0.2915),
#   tensor(0.2504),
#   tensor(0.2146),
#   tensor(0.2453),
#   tensor(0.2224),
#   tensor(0.2196),
#   tensor(0.2046),
#   tensor(0.2092),
#   tensor(0.2142),
#   tensor(0.1795),
#   tensor(0.1649),
#   tensor(0.1756),
#   tensor(0.1683),
#   tensor(0.1560),
#   tensor(0.1647)]]

# %%
TRAIN_ACC
# Out:
# [[0.1255,
#   0.133,
#   0.18650000000000003,
#   0.1965,
#   0.21000000000000005,
#   0.225,
#   0.23199999999999998,
#   0.25150000000000006,
#   0.26649999999999996,
#   0.27349999999999997,
#   0.29300000000000004,
#   0.28450000000000003,
#   0.3065,
#   0.31299999999999994,
#   0.31599999999999995,
#   0.323,
#   0.32399999999999995,
#   0.32600000000000007,
#   0.35750000000000004,
#   0.33799999999999997,
#   0.3625,
#   0.376,
#   0.3685,
#   0.3835,
#   0.393,
#   0.39949999999999997,
#   0.4370000000000001,
#   0.44700000000000006,
#   0.43800000000000006,
#   0.44000000000000006,
#   0.4675000000000001,
#   0.471,
#   0.4635000000000001,
#   0.5040000000000002,
#   0.5125,
#   0.5205,
#   0.5155000000000001,
#   0.5394999999999999,
#   0.5465,
#   0.5745000000000001],
#  [0.1375,
#   0.5055,
#   0.6855,
#   0.7929999999999999,
#   0.859,
#   0.8880000000000002,
#   0.9045,
#   0.9205,
#   0.9305000000000001,
#   0.9424999999999999,
#   0.9404999999999999,
#   0.9445,
#   0.9664999999999999,
#   0.9594999999999999,
#   0.9525,
#   0.9689999999999998,
#   0.9785,
#   0.9780000000000001,
#   0.9804999999999999,
#   0.9869999999999999,
#   0.9854999999999998,
#   0.977,
#   0.9784999999999998,
#   0.9884999999999999,
#   0.9884999999999999,
#   0.9914999999999999,
#   0.9955,
#   0.993,
#   0.982,
#   0.9899999999999999,
#   0.9760000000000002,
#   0.9894999999999999,
#   0.9925,
#   0.9949999999999999,
#   0.9974999999999998,
#   0.9959999999999998,
#   0.999,
#   0.9889999999999999,
#   0.9889999999999999,
#   0.9814999999999999],
#  [0.12800000000000003,
#   0.306,
#   0.5095000000000002,
#   0.6305000000000001,
#   0.6904999999999999,
#   0.722,
#   0.7235,
#   0.759,
#   0.764,
#   0.7754999999999999,
#   0.7875,
#   0.8030000000000003,
#   0.8155000000000001,
#   0.8295,
#   0.833,
#   0.842,
#   0.8554999999999999,
#   0.8564999999999999,
#   0.8755,
#   0.873,
#   0.8765000000000003,
#   0.884,
#   0.8895,
#   0.9029999999999999,
#   0.8905,
#   0.8944999999999999,
#   0.901,
#   0.9169999999999998,
#   0.9049999999999999,
#   0.914,
#   0.9179999999999999,
#   0.924,
#   0.9184999999999999,
#   0.9199999999999999,
#   0.9350000000000002,
#   0.9399999999999997,
#   0.9374999999999998,
#   0.9369999999999999,
#   0.9375,
#   0.9400000000000001]]

# %%
TEST_ACC
# Out:
# [[0.124,
#   0.15599999999999997,
#   0.205,
#   0.21699999999999994,
#   0.22199999999999998,
#   0.22400000000000003,
#   0.24000000000000005,
#   0.24699999999999997,
#   0.23900000000000002,
#   0.254,
#   0.269,
#   0.26000000000000006,
#   0.244,
#   0.286,
#   0.274,
#   0.273,
#   0.252,
#   0.263,
#   0.29,
#   0.292,
#   0.296,
#   0.2920000000000001,
#   0.29200000000000004,
#   0.267,
#   0.28,
#   0.29800000000000004,
#   0.29800000000000004,
#   0.2919999999999999,
#   0.304,
#   0.29000000000000004,
#   0.29100000000000004,
#   0.304,
#   0.27799999999999997,
#   0.27999999999999997,
#   0.291,
#   0.29500000000000004,
#   0.28600000000000003,
#   0.29900000000000004,
#   0.298,
#   0.306],
#  [0.25600000000000006,
#   0.607,
#   0.682,
#   0.755,
#   0.807,
#   0.8099999999999999,
#   0.8400000000000001,
#   0.842,
#   0.851,
#   0.8520000000000001,
#   0.843,
#   0.851,
#   0.868,
#   0.8710000000000001,
#   0.868,
#   0.8699999999999999,
#   0.89,
#   0.8739999999999999,
#   0.8780000000000001,
#   0.8800000000000001,
#   0.8949999999999999,
#   0.8550000000000001,
#   0.8989999999999998,
#   0.897,
#   0.885,
#   0.889,
#   0.8880000000000001,
#   0.876,
#   0.8869999999999999,
#   0.844,
#   0.8939999999999999,
#   0.9,
#   0.889,
#   0.8959999999999999,
#   0.9019999999999999,
#   0.8869999999999999,
#   0.8940000000000001,
#   0.8880000000000001,
#   0.883,
#   0.835],
#  [0.19999999999999998,
#   0.39099999999999996,
#   0.5890000000000001,
#   0.637,
#   0.671,
#   0.6379999999999999,
#   0.692,
#   0.6980000000000001,
#   0.716,
#   0.74,
#   0.733,
#   0.726,
#   0.77,
#   0.744,
#   0.768,
#   0.781,
#   0.7899999999999999,
#   0.7900000000000001,
#   0.795,
#   0.8049999999999999,
#   0.7849999999999999,
#   0.7920000000000001,
#   0.8140000000000001,
#   0.7950000000000002,
#   0.7939999999999999,
#   0.793,
#   0.8110000000000002,
#   0.818,
#   0.799,
#   0.8029999999999999,
#   0.821,
#   0.804,
#   0.8239999999999998,
#   0.8110000000000002,
#   0.8130000000000001,
#   0.812,
#   0.819,
#   0.8099999999999999,
#   0.8039999999999999,
#   0.7869999999999999]]

# %%
a = TEST_ACC
b = TRAIN_ACC
c = AVE_LOSS

# %%
a
b
c

# %%
samplers, loaders, num_batches, dim, num_channel = load_data(data)

# visualization
# get some random training images
dataiter = iter(loaders['train'])
images, labels = dataiter.next()
# show images
# fig, ax = plt.subplots()
# torchvision.utils.make_grid(images))
imshow(torchvision.utils.make_grid(images))
# ('fashion.png');
# ('fashion.png');
# Out:
# =====================================
# The dataset we are training: cifar
# Files already downloaded and verified
# Files already downloaded and verified
# Training on 2000 images
# (testing on 1000) for 15 epochs
# Maximum MPS bond dimension = 20
#  * Fixed bond dimensions
#  * Open boundary conditions
# Using Adam w/ learning rate = 1.0e-04

# %%
# Cifar
if num_channel == 3:
    size = [num_channel, batch_size, dim**2]
else:
    size = [batch_size, dim**2]
        
for inputs, labels in loaders['train']:
    inputs, labels = inputs.view(size), labels.data
    print(inputs.view(size))

# %%
# GPU
# reference: https://github.com/pytorch/tutorials/blob/master/beginner_source/blitz/cifar10_tutorial.py
########################################################################
# Okay, so what next?
#
# How do we run these neural networks on the GPU?
#
# Training on GPU
# ----------------
# Just like how you transfer a Tensor onto the GPU, you transfer the neural
# net onto the GPU.
#
# Let's first define our device as the first visible cuda device if we have
# CUDA available:

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)

########################################################################
# The rest of this section assumes that ``device`` is a CUDA device.
#
# Then these methods will recursively go over all modules and convert their
# parameters and buffers to CUDA tensors:
#
# .. code:: python
#
#     net.to(device)
#
#
# Remember that you will have to send the inputs and targets at every step
# to the GPU too:
#
# .. code:: python
#
#         inputs, labels = data[0].to(device), data[1].to(device)
#
# Why dont I notice MASSIVE speedup compared to CPU? Because your network
# is really small.
#
# **Exercise:** Try increasing the width of your network (argument 2 of
# the first ``nn.Conv2d``, and argument 1 of the second ``nn.Conv2d`` –
# they need to be the same number), see what kind of speedup you get.
#
# **Goals achieved**:
#
# - Understanding PyTorch's Tensor library and neural networks at a high level.
# - Train a small neural network to classify images
#
# Training on multiple GPUs
# -------------------------
# If you want to see even more MASSIVE speedup using all of your GPUs,
# please check out :doc:`data_parallel_tutorial`.
#
# Where do I go next?
# -------------------
#
# -  :doc:`Train neural nets to play video games </intermediate/reinforcement_q_learning>`
# -  `Train a state-of-the-art ResNet network on imagenet`_
# -  `Train a face generator using Generative Adversarial Networks`_
# -  `Train a word-level language model using Recurrent LSTM networks`_
# -  `More examples`_
# -  `More tutorials`_
# -  `Discuss PyTorch on the Forums`_
# -  `Chat with other users on Slack`_
#
# .. _Train a state-of-the-art ResNet network on imagenet: https://github.com/pytorch/examples/tree/master/imagenet
# .. _Train a face generator using Generative Adversarial Networks: https://github.com/pytorch/examples/tree/master/dcgan
# .. _Train a word-level language model using Recurrent LSTM networks: https://github.com/pytorch/examples/tree/master/word_language_model
# .. _More examples: https://github.com/pytorch/examples
# .. _More tutorials: https://github.com/pytorch/tutorials
# .. _Discuss PyTorch on the Forums: https://discuss.pytorch.org/
# .. _Chat with other users on Slack: https://pytorch.slack.com/messages/beginner/

# %%
for i in TRAIN_ACC:
    for j in i:
        print(float(j))
    print("=======")
# Out:
# 0.1255
# 0.133
# 0.18650000000000003
# 0.1965
# 0.21000000000000005
# 0.225
# 0.23199999999999998
# 0.25150000000000006
# 0.26649999999999996
# 0.27349999999999997
# 0.29300000000000004
# 0.28450000000000003
# 0.3065
# 0.31299999999999994
# 0.31599999999999995
# 0.323
# 0.32399999999999995
# 0.32600000000000007
# 0.35750000000000004
# 0.33799999999999997
# 0.3625
# 0.376
# 0.3685
# 0.3835
# 0.393
# 0.39949999999999997
# 0.4370000000000001
# 0.44700000000000006
# 0.43800000000000006
# 0.44000000000000006
# 0.4675000000000001
# 0.471
# 0.4635000000000001
# 0.5040000000000002
# 0.5125
# 0.5205
# 0.5155000000000001
# 0.5394999999999999
# 0.5465
# 0.5745000000000001
# =======
# 0.1375
# 0.5055
# 0.6855
# 0.7929999999999999
# 0.859
# 0.8880000000000002
# 0.9045
# 0.9205
# 0.9305000000000001
# 0.9424999999999999
# 0.9404999999999999
# 0.9445
# 0.9664999999999999
# 0.9594999999999999
# 0.9525
# 0.9689999999999998
# 0.9785
# 0.9780000000000001
# 0.9804999999999999
# 0.9869999999999999
# 0.9854999999999998
# 0.977
# 0.9784999999999998
# 0.9884999999999999
# 0.9884999999999999
# 0.9914999999999999
# 0.9955
# 0.993
# 0.982
# 0.9899999999999999
# 0.9760000000000002
# 0.9894999999999999
# 0.9925
# 0.9949999999999999
# 0.9974999999999998
# 0.9959999999999998
# 0.999
# 0.9889999999999999
# 0.9889999999999999
# 0.9814999999999999
# =======
# 0.12800000000000003
# 0.306
# 0.5095000000000002
# 0.6305000000000001
# 0.6904999999999999
# 0.722
# 0.7235
# 0.759
# 0.764
# 0.7754999999999999
# 0.7875
# 0.8030000000000003
# 0.8155000000000001
# 0.8295
# 0.833
# 0.842
# 0.8554999999999999
# 0.8564999999999999
# 0.8755
# 0.873
# 0.8765000000000003
# 0.884
# 0.8895
# 0.9029999999999999
# 0.8905
# 0.8944999999999999
# 0.901
# 0.9169999999999998
# 0.9049999999999999
# 0.914
# 0.9179999999999999
# 0.924
# 0.9184999999999999
# 0.9199999999999999
# 0.9350000000000002
# 0.9399999999999997
# 0.9374999999999998
# 0.9369999999999999
# 0.9375
# 0.9400000000000001
# =======

# %%
loss_cpu=open('loss_cpu.txt','w')

loss_cpu.writelines(AVE_LOSS)
loss_cpu.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-698cc486af1b> in <module>
#       1 loss_cpu=open('loss_cpu.txt','w')
#       2
# ----> 3 loss_cpu.writelines(AVE_LOSS)
#       4 loss_cpu.close()
#
# TypeError: write() argument must be str, not list
